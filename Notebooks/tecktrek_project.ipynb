# %%
import pandas as pd
import numpy as np
import random

# %%
# data loading
raw_customers_df = pd.read_csv("../Datasets/olist_customers_dataset.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
customers_df = raw_customers_df.copy()
raw_geo_location_df = pd.read_csv("../Datasets/olist_geolocation_dataset.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
geo_location_df = raw_geo_location_df.copy()
raw_order_items_df = pd.read_csv("../Datasets/olist_order_items_dataset.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
order_items_df = raw_order_items_df.copy()
raw_order_payments_df = pd.read_csv("../Datasets/olist_order_payments_dataset.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
order_payments_df = raw_order_payments_df.copy()
raw_order_reviews_df = pd.read_csv("../Datasets/olist_order_reviews_dataset.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
order_reviews_df = raw_order_reviews_df.copy()
raw_orders_df = pd.read_csv("../Datasets/olist_orders_dataset.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
orders_df = raw_orders_df.copy()
raw_products_df = pd.read_csv("../Datasets/olist_products_dataset.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
products_df = raw_products_df.copy()
raw_sellers_df = pd.read_csv("../Datasets/olist_sellers_dataset.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
sellers_df = raw_sellers_df.copy()
raw_product_translation_df = pd.read_csv("../Datasets/product_category_name_translation.csv", na_values=['',' ', 'NA', 'na', 'N/A', 'n/a', 'Null', 'null', '-', 'Missing', 'missing'])
product_translation_df = raw_product_translation_df.copy()

# %%
# info
random.seed(42)

# %%
print(f"Customers shape: {customers_df.shape}\nHead:\n{customers_df.head()}\nTail:\n{customers_df.tail()}\n\n")
# Out:
# Customers shape: (99441, 5)
# Head:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# Tail:
#                             customer_id                customer_unique_id  \
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix    customer_city customer_state
# 99436                      3937        sao paulo             SP
# 99437                      6764  taboao da serra             SP
# 99438                     60115        fortaleza             CE
# 99439                     92120           canoas             RS
# 99440                      6703            cotia             SP

# %%
print(f"Geo Location shape: {geo_location_df.shape}\nHead:\n{geo_location_df.head()}\nTail:\n{geo_location_df.tail()}\n\n")
# Out:
# Geo Location shape: (1000163, 5)
# Head:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP
# Tail:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 1000158         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000161  david canabarro                RS
# 1000162         tapejara                RS

# %%
print(f"Order-items shape: {order_items_df.shape}\nHead:\n{order_items_df.head()}\nTail:\n{order_items_df.tail()}\n\n")
# Out:
# Order-items shape: (112650, 7)
# Head:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14
# Tail:
#                                 order_id  order_item_id  \
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79

# %%
print(f"Order-payements shape: {order_payments_df.shape}\nHead:\n{order_payments_df.head()}\nTail:\n{order_payments_df.tail()}\n\n")
# Out:
# Order-payements shape: (103886, 5)
# Head:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45
# Tail:
#                                 order_id  payment_sequential payment_type  \
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58

# %%
print(f"Order-reviews shape: {order_reviews_df.shape}\nHead:\n{order_reviews_df.head()}\nTail:\n{order_reviews_df.tail()}\n\n")
# Out:
# Order-reviews shape: (99224, 7)
# Head:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53
# Tail:
#                               review_id                          order_id  \
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 99219             5                  NaN
# 99220             5                  NaN
# 99221             5                  NaN
# 99222             4                  NaN
# 99223             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 99219                                                NaN  2018-07-07 00:00:00
# 99220                                                NaN  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                                NaN  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49

# %%
print(f"Orders shape: {orders_df.shape}\nHead:\n{orders_df.head()}\nTail:\n{orders_df.tail()}\n\n")
# Out:
# Orders shape: (99441, 8)
# Head:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00
# Tail:
#                                order_id                       customer_id  \
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 99436           2017-03-28 00:00:00
# 99437           2018-03-02 00:00:00
# 99438           2017-09-27 00:00:00
# 99439           2018-02-15 00:00:00
# 99440           2018-04-03 00:00:00

# %%
print(f"Products shape: {products_df.shape}\nHead: \n{products_df.head()}\nTail:\n{products_df.tail()}\n\n")
# Out:
# Products shape: (32951, 9)
# Head:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
# Tail:
#                              product_id              product_category_name  \
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 32946           12300.0               40.0               40.0
# 32947            1700.0               16.0               19.0
# 32948            1400.0               27.0                7.0
# 32949             700.0               31.0               13.0
# 32950            2083.0               12.0                2.0
#
#        product_width_cm
# 32946              40.0
# 32947              16.0
# 32948              27.0
# 32949              20.0
# 32950               7.0

# %%
print(f"Sellers shape: {sellers_df.shape}\nHead:\n{sellers_df.head()}\nTail:\n{sellers_df.tail()}\n\n")
# Out:
# Sellers shape: (3095, 4)
# Head:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# Tail:
#                              seller_id  seller_zip_code_prefix seller_city  \
# 3090  98dddbc4601dd4443ca174359b237166                   87111     sarandi
# 3091  f8201cab383e484733266d1906e2fdfa                   88137     palhoca
# 3092  74871d19219c7d518d0090283e03c137                    4650   sao paulo
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080     pelotas
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051     taubate
#
#      seller_state
# 3090           PR
# 3091           SC
# 3092           SP
# 3093           RS
# 3094           SP

# %%
print(f"Product translation shape: {product_translation_df.shape}\nHead:\n{product_translation_df.head()}\nTail:\n{product_translation_df.tail()}\n")
# Out:
# Product translation shape: (71, 2)
# Head:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor
# Tail:
#             product_category_name product_category_name_english
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services

# %% [markdown]
# # Audit
# Info and Describe

# %%
print("Customer:")
customers_df.info()
print('\n')
print(customers_df.describe())
print('\n')
# Out:
# Customer:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB
#
#
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
print("Geo-location:")
geo_location_df.info()
print('\n')
print(geo_location_df.describe())
print('\n')
# Out:
# Geo-location:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  str
#  4   geolocation_state            1000163 non-null  str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 38.2 MB
#
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
print("Order-items:")
order_items_df.info()
print('\n')
print(order_items_df.describe())
print('\n')
# Out:
# Order-items:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  str
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 6.0 MB
#
#
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# all prices > 0

# %%
print("Order-payments:")
order_payments_df.info()
print('\n')
print(order_payments_df.describe())
print('\n')
print(order_payments_df['payment_type'].value_counts())
# Out:
# Order-payments:
# <class 'pandas.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  str
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  str
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 4.0 MB
#
#
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000
#
#
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# payment types consistent

# %%
print("Order-reviews:")
order_reviews_df.info()
print('\n')
print(order_reviews_df.describe())
print('\n')
# Out:
# Order-reviews:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  str
#  1   order_id                 99224 non-null  str
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11565 non-null  str
#  4   review_comment_message   40965 non-null  str
#  5   review_creation_date     99224 non-null  str
#  6   review_answer_timestamp  99224 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 5.3 MB
#
#
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# all reviews between 1 and 5

# %%
print("Orders:")
orders_df.info()
print('\n')
print(orders_df.describe())
print('\n')
# Out:
# Orders:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB
#
#
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-03-31 15:08:21  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-14 20:02:44
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %%
print("Products:")
products_df.info()
print('\n')
print(products_df.describe())
print('\n')
# Out:
# Products:
# <class 'pandas.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  str
#  1   product_category_name       32341 non-null  str
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), str(2)
# memory usage: 2.3 MB
#
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
print("Sellers:")
sellers_df.info()
print('\n')
print(sellers_df.describe())
print('\n')
# Out:
# Sellers:
# <class 'pandas.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   str
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   str
#  3   seller_state            3095 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 96.8 KB
#
#
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
print("Product Translation:")
product_translation_df.info()
print('\n')
print(product_translation_df.describe())
# Out:
# Product Translation:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     str
#  1   product_category_name_english  71 non-null     str
# dtypes: str(2)
# memory usage: 1.2 KB
#
#
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# # Nulls and Duplicates

# %%
# customers df
print("Customers:")
print(customers_df.isnull().sum(), '\n')
print(f"Null percentage: \n{customers_df.isnull().sum()/ len(customers_df) * 100}\n")
print(customers_df.duplicated().sum(), '\n')
# Out:
# Customers:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Null percentage:
# customer_id                 0.0
# customer_unique_id          0.0
# customer_zip_code_prefix    0.0
# customer_city               0.0
# customer_state              0.0
# dtype: float64
#
# 0

# %%
# geo location df
print("Geo-location:")
print(geo_location_df.isnull().sum(), '\n')
print(f"Null percentage: \n{geo_location_df.isnull().sum()/ len(geo_location_df) * 100}\n")
print(geo_location_df.duplicated().sum(), '\n')
# Out:
# Geo-location:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Null percentage:
# geolocation_zip_code_prefix    0.0
# geolocation_lat                0.0
# geolocation_lng                0.0
# geolocation_city               0.0
# geolocation_state              0.0
# dtype: float64
#
# 261831

# %%
# order items df
print("Order-items:")
print(order_items_df.isnull().sum(), '\n')
print(f"Null percentage: \n{order_items_df.isnull().sum()/ len(order_items_df) * 100}\n")
print(order_items_df.duplicated().sum(), '\n')
# Out:
# Order-items:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Null percentage:
# order_id               0.0
# order_item_id          0.0
# product_id             0.0
# seller_id              0.0
# shipping_limit_date    0.0
# price                  0.0
# freight_value          0.0
# dtype: float64
#
# 0

# %%
# order payments df
print("Order-payments:")
print(order_payments_df.isnull().sum(), '\n')
print(f"Null percentage: \n{order_payments_df.isnull().sum()/ len(order_payments_df) * 100}\n")
print(order_payments_df.duplicated().sum(), '\n')
# Out:
# Order-payments:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Null percentage:
# order_id                0.0
# payment_sequential      0.0
# payment_type            0.0
# payment_installments    0.0
# payment_value           0.0
# dtype: float64
#
# 0

# %%
# order reviews df
print("Order-reviews:")
print(order_reviews_df.isnull().sum(), '\n')
print(f"Null percentage: \n{order_reviews_df.isnull().sum()/ len(order_reviews_df) * 100}\n")
print(order_reviews_df.duplicated().sum(), '\n')
# Out:
# Order-reviews:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87659
# review_comment_message     58259
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64
#
# Null percentage:
# review_id                   0.000000
# order_id                    0.000000
# review_score                0.000000
# review_comment_title       88.344554
# review_comment_message     58.714625
# review_creation_date        0.000000
# review_answer_timestamp     0.000000
# dtype: float64
#
# 0

# %%
# orders df
print("Orders:")
print(orders_df.isnull().sum(), '\n')
print(f"Null percentage: \n{orders_df.isnull().sum()/ len(orders_df) * 100}\n")
print(orders_df.duplicated().sum(), '\n')
print(f"Order id duplicated:\n {orders_df['order_id'].duplicated().sum()}\n")
# Out:
# Orders:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# Null percentage:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.160899
# order_delivered_carrier_date     1.793023
# order_delivered_customer_date    2.981668
# order_estimated_delivery_date    0.000000
# dtype: float64
#
# 0
#
# Order id duplicated:
#  0

# %%
# products df
print("Products:")
print(products_df.isnull().sum(), '\n')
print(f"Null percentage: \n{products_df.isnull().sum()/ len(products_df) * 100}\n")
print(products_df.duplicated().sum(), '\n')
# Out:
# Products:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# Null percentage:
# product_id                    0.000000
# product_category_name         1.851234
# product_name_lenght           1.851234
# product_description_lenght    1.851234
# product_photos_qty            1.851234
# product_weight_g              0.006070
# product_length_cm             0.006070
# product_height_cm             0.006070
# product_width_cm              0.006070
# dtype: float64
#
# 0

# %%
# sellers df
print("Sellers:")
print(sellers_df.isnull().sum(), '\n')
print(f"Null percentage: \n{sellers_df.isnull().sum()/ len(sellers_df) * 100}\n")
print(sellers_df.duplicated().sum(), '\n')
# Out:
# Sellers:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# Null percentage:
# seller_id                 0.0
# seller_zip_code_prefix    0.0
# seller_city               0.0
# seller_state              0.0
# dtype: float64
#
# 0

# %%
# product translation
print("Product Translation:")
print(product_translation_df.isnull().sum(), '\n')
print(f"Null percentage: \n{product_translation_df.isnull().sum()/ len(product_translation_df) * 100}\n")
print(product_translation_df.duplicated().sum(), '\n')
# Out:
# Product Translation:
# product_category_name            0
# product_category_name_english    0
# dtype: int64
#
# Null percentage:
# product_category_name            0.0
# product_category_name_english    0.0
# dtype: float64
#
# 0

# %% [markdown]
# No hidden nulls (removed in import statements), many duplicates in geo location which makes sense since any customer ordering multiple times or people ordering from the same location would be considered a duplicate. Order id also has no duplicates showing it has integrity

# %% [markdown]
# Some products have dimension details and product id but no name or description

# %%
products_with_missing_details = products_df[products_df.isna().any(axis=1)]['product_id']

# %%
order_items_df[order_items_df['product_id'].isin(products_with_missing_details)]
# Out:
#                                 order_id  order_item_id  \
# 123     0046e1d57f4c07c8c92ab26be8c3dfc0              1
# 125     00482f2670787292280e0a8153d82467              1
# 132     004f5d8f238e8908e6864b874eda3391              1
# 142     0057199db02d1a5ef41bacbf41f8f63b              1
# 171     006cb7cafc99b29548d4f412c7f9f493              1
# ...                                  ...            ...
# 112306  ff24fec69b7f3d30f9dc1ab3aee7c179              1
# 112333  ff3024474be86400847879103757d1fd              1
# 112350  ff3a45ee744a7c1f8096d2e72c1a23e4              1
# 112438  ff7b636282b98e0aa524264b295ed928              1
# 112501  ffa5e4c604dea4f0a59d19cc2322ac19              2
#
#                               product_id                         seller_id  \
# 123     ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
# 125     a9c404971d1a5b1cbc2e4070e02731fd  702835e4b785b67a084280efca355756
# 132     5a848e4ab52fd5445cdc07aab1c40e48  c826c40d7b19f62a09e2d7c5e7295ee2
# 142     41eee23c25f7a574dfaf8d5c151dbb12  e5a3438891c0bfdb9394643f95273d8e
# 171     e10758160da97891c2fdcbc35f0f031d  323ce52b5b81df2cd804b017b7f09aa7
# ...                                  ...                               ...
# 112306  5a848e4ab52fd5445cdc07aab1c40e48  c826c40d7b19f62a09e2d7c5e7295ee2
# 112333  f9b1795281ce51b1cf39ef6d101ae8ab  3771c85bac139d2344864ede5d9341e3
# 112350  b61d1388a17e3f547d2bc218df02335b  07017df32dc5f2f1d2801e579548d620
# 112438  431df35e52c10451171d8037482eeb43  6cd68b3ed6d59aaa9fece558ad360c0a
# 112501  bd421826916d3e1d445cb860cea3c0fb  59cd88080b93f3c18508673122d26169
#
#         shipping_limit_date   price  freight_value
# 123     2017-10-02 15:49:17    7.79           7.78
# 125     2017-02-17 16:18:07    7.60          10.96
# 132     2018-03-06 09:29:25  122.99          15.61
# 142     2018-01-25 09:07:51   20.30          16.79
# 171     2018-02-22 13:35:28   56.00          14.14
# ...                     ...     ...            ...
# 112306  2018-02-01 02:40:12  122.99          15.61
# 112333  2017-11-21 03:55:39   39.90           9.94
# 112350  2017-05-10 10:15:19  139.00          21.42
# 112438  2018-02-22 15:35:35   49.90          15.11
# 112501  2017-12-11 08:41:20   29.99          15.10
#
# [1604 rows x 7 columns]

# %% [markdown]
# Even though these products have missing details, people still order them, so its best not to remove these entries from the dataframe

# %%
def object_clean(df):
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col] = df[col].str.strip()
            df[col] = df[col].astype('category')
    return df

# %%
customers_df = object_clean(customers_df)
geo_location_df = object_clean(geo_location_df)
order_items_df = object_clean(order_items_df)
order_payments_df = object_clean(order_payments_df)
order_reviews_df = object_clean(order_reviews_df)
orders_df = object_clean(orders_df)
products_df = object_clean(products_df)
sellers_df = object_clean(sellers_df)
product_translation_df = object_clean(product_translation_df)

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders_df['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %% [markdown]
# No indicator for refunded/returned order

# %%
for date_col in ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']:
    orders_df[date_col] = pd.to_datetime(orders_df[date_col].astype(str), errors='coerce')

# %%
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  datetime64[us]
#  4   order_approved_at              99281 non-null  datetime64[us]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[us]
#  6   order_delivered_customer_date  96476 non-null  datetime64[us]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[us]
# dtypes: datetime64[us](5), str(3)
# memory usage: 6.1 MB

# %% [markdown]
# null values in columns 5 and 6 due to order not yet being delivered

# %%
order_reviews_df['review_creation_date'] = pd.to_datetime(order_reviews_df['review_creation_date'].astype(str), errors='coerce')
order_reviews_df['review_answer_timestamp'] = pd.to_datetime(order_reviews_df['review_answer_timestamp'].astype(str), errors='coerce')
order_reviews_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  str
#  1   order_id                 99224 non-null  str
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11565 non-null  str
#  4   review_comment_message   40965 non-null  str
#  5   review_creation_date     99224 non-null  datetime64[us]
#  6   review_answer_timestamp  99224 non-null  datetime64[us]
# dtypes: datetime64[us](2), int64(1), str(4)
# memory usage: 5.3 MB

# %%
order_items_df['shipping_limit_date'] = pd.to_datetime(order_items_df['shipping_limit_date'].astype(str), errors='coerce')
order_items_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  datetime64[us]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[us](1), float64(2), int64(1), str(3)
# memory usage: 6.0 MB

# %% [markdown]
# Datatype conversions done.
#
# All values fall within valid ranges (ex: reviews between 1 and 5).
#
# No duplicates.
#
# Null values acceptable in business context.
#
# Labels consistent and standardized

# %% [markdown]
# # Feature Engineering & EDA

# %%
orders_df['delivery_delay'] = (
    orders_df['order_delivered_customer_date']
    - orders_df['order_estimated_delivery_date']
).dt.days

print(f"Delivery delay:\n{orders_df['delivery_delay'].head(10)}\n")
# Out:
# Delivery delay:
# 0    -8.0
# 1    -6.0
# 2   -18.0
# 3   -13.0
# 4   -10.0
# 5    -6.0
# 6     NaN
# 7   -12.0
# 8   -32.0
# 9    -7.0
# Name: delivery_delay, dtype: float64

# %%
orders_df['is_late'] = (
    orders_df['order_delivered_customer_date']
    > orders_df['order_estimated_delivery_date']
).astype(int)

print(f"Is late:\n{orders_df['is_late'].value_counts()}\n")
# Out:
# Is late:
# is_late
# 0    91614
# 1     7827
# Name: count, dtype: int64

# %%
orders_df.loc[orders_df['delivery_delay'].notna(), 'is_late'] = (
    orders_df.loc[orders_df['delivery_delay'].notna(), 'delivery_delay'] > 0
).astype(int)

# %%
orders_df['order_year'] = orders_df['order_purchase_timestamp'].dt.year

orders_df['order_month'] = orders_df['order_purchase_timestamp'].dt.month

orders_df['order_weekday_name'] = orders_df['order_purchase_timestamp'].dt.day_name()

orders_df['order_hour'] = orders_df['order_purchase_timestamp'].dt.hour

orders_df['is_weekend'] = (
    orders_df['order_purchase_timestamp'].dt.dayofweek >= 5
).astype(int)

# %%
weekday_delay = (
    orders_df.groupby('order_weekday_name')['is_late']
    .mean()*100
)

weekday_delay
# Out:
# order_weekday_name
# Friday       6.797904
# Monday       7.217832
# Saturday     6.392946
# Sunday       6.053512
# Thursday     6.117472
# Tuesday      6.847084
# Wednesday    6.365741
# Name: is_late, dtype: float64

# %%
best_day = weekday_delay.idxmin()
best_rate = weekday_delay.min()
print("Best day:", best_day)
print("Late delivery rate:", best_rate, "%")

worst_day = weekday_delay.idxmax()
worst_rate = weekday_delay.max()
print("Worst day:", worst_day)
print("Late delivery rate:", worst_rate, "%")
# Out:
# Best day: Sunday
# Late delivery rate: 6.053511705685619 %
# Worst day: Monday
# Late delivery rate: 7.217831563348975 %

# %%
order_price = (
    order_items_df
    .groupby('order_id')['price']
    .sum()
    .reset_index(name='total_price')
)

# %%
orders_df = orders_df.merge(
    order_price,
    on='order_id',
    how='left'
)
orders_df[['order_id', 'total_price']].head(10)
# Out:
#                            order_id  total_price
# 0  e481f51cbdc54678b7cc49136f2d6af7        29.99
# 1  53cdb2fc8bc7dce0b6741e2150273451       118.70
# 2  47770eb9100c2d0c44946d9cf07ec65d       159.90
# 3  949d5b44dbf5de918fe9c16f97b45f8a        45.00
# 4  ad21c59c0840e6cb83a9ceb5573f8159        19.90
# 5  a4591c265e18cb1dcee52889e2d8acc3       147.90
# 6  136cce7faa42fdb2cefd53fdc79a6098        49.90
# 7  6514b8ad8028c9f2cc2374ded245783f        59.99
# 8  76c6e866289321a7c93b82b54852dc33        19.90
# 9  e69bfb5eb88e0ed6a785585b27e16dbf       149.99

# %%
orders_df['price_group'] = pd.qcut(
    orders_df['total_price'],
    q=4,
    labels=['Low', 'Medium', 'High', 'Very High']
)

# %%
orders_df.groupby('price_group')['is_late'].mean() * 100
# Out:
# price_group
# Low          5.804653
# Medium       6.595546
# High         6.658027
# Very High    7.441482
# Name: is_late, dtype: float64

# %%
order_freight = (
    order_items_df
    .groupby('order_id')['freight_value']
    .sum()
    .reset_index(name='total_freight')
)

# %%
orders_df = orders_df.merge(
    order_freight,
    on='order_id',
    how='left'
)

# %%
orders_df[['order_id', 'total_price', 'total_freight']].head(10)
# Out:
#                            order_id  total_price  total_freight
# 0  e481f51cbdc54678b7cc49136f2d6af7        29.99           8.72
# 1  53cdb2fc8bc7dce0b6741e2150273451       118.70          22.76
# 2  47770eb9100c2d0c44946d9cf07ec65d       159.90          19.22
# 3  949d5b44dbf5de918fe9c16f97b45f8a        45.00          27.20
# 4  ad21c59c0840e6cb83a9ceb5573f8159        19.90           8.72
# 5  a4591c265e18cb1dcee52889e2d8acc3       147.90          27.36
# 6  136cce7faa42fdb2cefd53fdc79a6098        49.90          16.05
# 7  6514b8ad8028c9f2cc2374ded245783f        59.99          15.17
# 8  76c6e866289321a7c93b82b54852dc33        19.90          16.05
# 9  e69bfb5eb88e0ed6a785585b27e16dbf       149.99          19.77

# %%
orders_df['total_freight'].describe()
# Out:
# count    98666.000000
# mean        22.823562
# std         21.650909
# min          0.000000
# 25%         13.850000
# 50%         17.170000
# 75%         24.040000
# max       1794.960000
# Name: total_freight, dtype: float64

# %%
orders_df['order_total_value'] = (
    orders_df['total_price'] +
    orders_df['total_freight']
)
orders_df[
    ['order_id', 'total_price', 'total_freight', 'order_total_value']
].head(10)
# Out:
#                            order_id  total_price  total_freight  \
# 0  e481f51cbdc54678b7cc49136f2d6af7        29.99           8.72
# 1  53cdb2fc8bc7dce0b6741e2150273451       118.70          22.76
# 2  47770eb9100c2d0c44946d9cf07ec65d       159.90          19.22
# 3  949d5b44dbf5de918fe9c16f97b45f8a        45.00          27.20
# 4  ad21c59c0840e6cb83a9ceb5573f8159        19.90           8.72
# 5  a4591c265e18cb1dcee52889e2d8acc3       147.90          27.36
# 6  136cce7faa42fdb2cefd53fdc79a6098        49.90          16.05
# 7  6514b8ad8028c9f2cc2374ded245783f        59.99          15.17
# 8  76c6e866289321a7c93b82b54852dc33        19.90          16.05
# 9  e69bfb5eb88e0ed6a785585b27e16dbf       149.99          19.77
#
#    order_total_value
# 0              38.71
# 1             141.46
# 2             179.12
# 3              72.20
# 4              28.62
# 5             175.26
# 6              65.95
# 7              75.16
# 8              35.95
# 9             169.76

# %%
item_count = (
    order_items_df
    .groupby('order_id')
    .size()
    .reset_index(name='total_items')
)

# %%
orders_df = orders_df.merge (
    item_count,
    on='order_id',
    how='left'
)

# %%
orders_df[
    ['order_id', 'total_items']
].head(30)
# Out:
#                             order_id  total_items
# 0   e481f51cbdc54678b7cc49136f2d6af7          1.0
# 1   53cdb2fc8bc7dce0b6741e2150273451          1.0
# 2   47770eb9100c2d0c44946d9cf07ec65d          1.0
# 3   949d5b44dbf5de918fe9c16f97b45f8a          1.0
# 4   ad21c59c0840e6cb83a9ceb5573f8159          1.0
# 5   a4591c265e18cb1dcee52889e2d8acc3          1.0
# 6   136cce7faa42fdb2cefd53fdc79a6098          1.0
# 7   6514b8ad8028c9f2cc2374ded245783f          1.0
# 8   76c6e866289321a7c93b82b54852dc33          1.0
# 9   e69bfb5eb88e0ed6a785585b27e16dbf          1.0
# 10  e6ce16cb79ec1d90b1da9085a6118aeb          2.0
# 11  34513ce0c4fab462a55830c0989c7edb          1.0
# 12  82566a660a982b15fb86e904c8d32918          1.0
# 13  5ff96c15d0b717ac6ad1f3d77225a350          1.0
# 14  432aaf21d85167c2c86ec9448c4e42cc          1.0
# 15  dcb36b511fcac050b97cd5c05de84dc3          1.0
# 16  403b97836b0c04a622354cf531062e5f          1.0
# 17  116f0b09343b49556bbad5f35bee0cdf          1.0
# 18  85ce859fd6dc634de8d2f1e290444043          1.0
# 19  83018ec114eee8641c97e08f7b4e926f          1.0
# 20  203096f03d82e0dffbc41ebc2e2bcfb7          1.0
# 21  f848643eec1d69395095eb3840d2051e          1.0
# 22  2807d0e504d6d4894d41672727bc139f          1.0
# 23  95266dbfb7e20354baba07964dac78d5          1.0
# 24  f3e7c359154d965827355f39d6b1fdac          1.0
# 25  fbf9ac61453ac646ce8ad9783d7d0af6          1.0
# 26  acce194856392f074dbf9dada14d8d82          2.0
# 27  dd78f560c270f1909639c11b925620ea          1.0
# 28  91b2a010e1e45e6ba3d133fa997597be          1.0
# 29  ecab90c9933c58908d3d6add7c6f5ae3          1.0

# %%
avg_item_price = (
    order_items_df
    .groupby('order_id')['price']
    .mean()
    .reset_index(name='average_item_price')
)

orders_df = orders_df.merge(
    avg_item_price,
    on='order_id',
    how='left'
)

# %%
seller_count = (
    order_items_df
    .groupby('order_id')['seller_id']
    .nunique()
    .reset_index(name='number_of_sellers')
)
orders_df = orders_df.merge(
    seller_count,
    on='order_id',
    how='left'
)

# %%
orders_df[
    ['order_id', 'number_of_sellers']
].head(30)
# Out:
#                             order_id  number_of_sellers
# 0   e481f51cbdc54678b7cc49136f2d6af7                1.0
# 1   53cdb2fc8bc7dce0b6741e2150273451                1.0
# 2   47770eb9100c2d0c44946d9cf07ec65d                1.0
# 3   949d5b44dbf5de918fe9c16f97b45f8a                1.0
# 4   ad21c59c0840e6cb83a9ceb5573f8159                1.0
# 5   a4591c265e18cb1dcee52889e2d8acc3                1.0
# 6   136cce7faa42fdb2cefd53fdc79a6098                1.0
# 7   6514b8ad8028c9f2cc2374ded245783f                1.0
# 8   76c6e866289321a7c93b82b54852dc33                1.0
# 9   e69bfb5eb88e0ed6a785585b27e16dbf                1.0
# 10  e6ce16cb79ec1d90b1da9085a6118aeb                1.0
# 11  34513ce0c4fab462a55830c0989c7edb                1.0
# 12  82566a660a982b15fb86e904c8d32918                1.0
# 13  5ff96c15d0b717ac6ad1f3d77225a350                1.0
# 14  432aaf21d85167c2c86ec9448c4e42cc                1.0
# 15  dcb36b511fcac050b97cd5c05de84dc3                1.0
# 16  403b97836b0c04a622354cf531062e5f                1.0
# 17  116f0b09343b49556bbad5f35bee0cdf                1.0
# 18  85ce859fd6dc634de8d2f1e290444043                1.0
# 19  83018ec114eee8641c97e08f7b4e926f                1.0
# 20  203096f03d82e0dffbc41ebc2e2bcfb7                1.0
# 21  f848643eec1d69395095eb3840d2051e                1.0
# 22  2807d0e504d6d4894d41672727bc139f                1.0
# 23  95266dbfb7e20354baba07964dac78d5                1.0
# 24  f3e7c359154d965827355f39d6b1fdac                1.0
# 25  fbf9ac61453ac646ce8ad9783d7d0af6                1.0
# 26  acce194856392f074dbf9dada14d8d82                2.0
# 27  dd78f560c270f1909639c11b925620ea                1.0
# 28  91b2a010e1e45e6ba3d133fa997597be                1.0
# 29  ecab90c9933c58908d3d6add7c6f5ae3                1.0

# %%
orders_df['freight_ratio'] = np.where(
    orders_df['total_price'] > 0,
    orders_df['total_freight'] / orders_df['total_price'],
    np.nan
)

# %%
orders_df[
    ['order_id', 'total_price', 'total_freight', 'freight_ratio']
].head()
# Out:
#                            order_id  total_price  total_freight  freight_ratio
# 0  e481f51cbdc54678b7cc49136f2d6af7        29.99           8.72       0.290764
# 1  53cdb2fc8bc7dce0b6741e2150273451       118.70          22.76       0.191744
# 2  47770eb9100c2d0c44946d9cf07ec65d       159.90          19.22       0.120200
# 3  949d5b44dbf5de918fe9c16f97b45f8a        45.00          27.20       0.604444
# 4  ad21c59c0840e6cb83a9ceb5573f8159        19.90           8.72       0.438191

# %%
orders_df = orders_df.merge(
    customers_df[['customer_id', 'customer_state']],
    on='customer_id',
    how='left'
)

# %%
orders_df[
    ['order_id', 'customer_id', 'customer_state']
].head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   customer_state
# 0             SP
# 1             BA
# 2             GO
# 3             RN
# 4             SP
# 5             PR
# 6             RS
# 7             RJ
# 8             RS
# 9             SP

# %%
items_products = order_items_df.merge(
    products_df[['product_id', 'product_category_name']],
    on='product_id',
    how='left'
)

# %%
import plotly.express as px
status_counts = orders_df['is_late'].value_counts()

fig = px.pie(
    values=status_counts.values,
    names=['On Time / Early' if x == 0 else 'Late'
           for x in status_counts.index],
    title='Delivery Status Distribution'
)

fig.show()

# %%
monthly_delay = (
    orders_df
    .groupby('order_month')['is_late']
    .mean()
    .reset_index()
)
monthly_delay['is_late'] *= 100
fig = px.line(
    monthly_delay,
    x='order_month',
    y='is_late',
    markers=True,
    title='Late Delivery Rate by Month',
    labels={
        'order_month': 'Month',
        'is_late': 'Late Delivery Rate (%)'
    }
)

fig.show()

# %%
weekday_delay = (
    orders_df.groupby('order_weekday_name')['is_late']
    .mean()
    .mul(100)
    .reset_index()
)

fig = px.bar(
    weekday_delay,
    x='order_weekday_name',
    y='is_late',
    title='Late Delivery Rate by Weekday',
    labels={
        'order_weekday': 'Day of Week',
        'is_late': 'Late Delivery Rate (%)'
    }
)

fig.show()

# %%
items_delay = (
    orders_df.groupby('is_late')['total_items']
    .mean()
    .reset_index()
)

items_delay['Delivery Status'] = items_delay['is_late'].map({
    0: 'On Time / Early',
    1: 'Late'
})

fig = px.bar(
    items_delay,
    x='Delivery Status',
    y='total_items',
    title='Average Number of Items by Delivery Status',
    labels={
        'total_items': 'Average Number of Items',
        'Delivery Status': 'Delivery Status'
    },
    text_auto='.2f'
)

fig.show()

# %%
state_delay = (
    orders_df.groupby('customer_state')['is_late']
    .mean()
    .mul(100)
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)
fig = px.bar(
    state_delay,
    x='customer_state',
    y='is_late',
    title='Top 10 States by Late Delivery Rate',
    labels={
        'customer_state': 'Customer State',
        'is_late': 'Late Delivery Rate (%)'
    }
)

fig.show()

# %%
fig = px.scatter(
    orders_df.sample(min(5000, len(orders_df)), random_state=42),
    x='order_total_value',
    y='freight_ratio',
    color='is_late',
    title='Freight Ratio vs Order Value',
    labels={
        'order_total_value': 'Order Total Value',
        'freight_ratio': 'Freight Ratio',
        'is_late': 'Late'
    }
)

fig.show()

# %%
freight_delay = (
    orders_df.groupby('is_late')['total_freight']
    .mean()
    .reset_index()
)

freight_delay['Delivery Status'] = freight_delay['is_late'].map({
    0: 'On Time / Early',
    1: 'Late'
})

fig = px.bar(
    freight_delay,
    x='Delivery Status',
    y='total_freight',
    title='Average Freight Cost by Delivery Status',
    labels={
        'Delivery Status': 'Delivery Status',
        'total_freight': 'Average Freight Cost'
    },
    text_auto='.2f'
)

fig.show()

# %%
freight_delay = (
    orders_df.groupby('is_late')['total_freight']
    .mean()
    .reset_index()
)

freight_delay['Delivery Status'] = freight_delay['is_late'].map({
    0: 'On Time / Early',
    1: 'Late'
})

fig = px.bar(
    freight_delay,
    x='Delivery Status',
    y='total_freight',
    title='Average Freight Cost by Delivery Status',
    labels={
        'Delivery Status': 'Delivery Status',
        'total_freight': 'Average Freight Cost'
    },
    text_auto='.2f'
)

fig.show()

# %%
features = [
    'order_year',
    'order_month',
    'order_weekday_name',
    'order_hour',
    'is_weekend',
    'total_price',
    'total_freight',
    'order_total_value',
    'total_items',
    'average_item_price',
    'number_of_sellers',
    'freight_ratio',
    'customer_state'
]

# %%
X = orders_df[features]

# %%
Y = orders_df['is_late']

# %%
categorical_features = X.select_dtypes(
    include=['str', 'object', 'category']
).columns.tolist()

numeric_features = X.select_dtypes(
    include=['number']
).columns.tolist()

print("Categorical Features:")
print(categorical_features)

print("\nNumerical Features:")
print(numeric_features)
# Out:
# Categorical Features:
# ['order_weekday_name', 'customer_state']
#
# Numerical Features:
# ['order_year', 'order_month', 'order_hour', 'is_weekend', 'total_price', 'total_freight', 'order_total_value', 'total_items', 'average_item_price', 'number_of_sellers', 'freight_ratio']

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

numeric_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_pipeline, numeric_features),
        ('cat', categorical_pipeline, categorical_features)
    ]
)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42,
    stratify=Y
)

# %%
Y.value_counts()
# Out:
# is_late
# 0    92906
# 1     6535
# Name: count, dtype: int64

# %% [markdown]
# The target variable is imbalanced: 93.4% Not Late vs. 6.6% Late. Therefore, class_weight='balanced' was used to improve the model's detection of late deliveries.

# %%
from sklearn.linear_model import LogisticRegression

logistic_model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(
        max_iter=1000,
        class_weight='balanced'
    ))
])

# %%
logistic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['order_year', 'order_month',
#                                                    'order_hour', 'is_weekend',
#                                                    'total_price',
#                                                    'total_freight',
#                                                    'order_total_value',
#                                                    'total_items',
#                                                    'average_item_price',
#                                                    'number_of_sellers',
#                                                    'freight_ratio']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['order_weekday_name',
#                                                    'customer_state'])])),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred_lr = logistic_model.predict(X_test)
y_prob_lr = logistic_model.predict_proba(X_test)[:, 1]
print(f"Predicted classes: {y_pred_lr[:10]}")
print(f"Predicted probabilities: {y_prob_lr[:10]}")
# Out:
# Predicted classes: [0 0 0 1 1 0 0 1 1 0]
# Predicted probabilities: [0.38664538 0.44786069 0.44300619 0.64226235 0.51087383 0.41975382
#  0.3177683  0.57501082 0.63479791 0.36866815]

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

print("Logistic Regression")
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("Precision:", precision_score(y_test, y_pred_lr, zero_division=0))
print("Recall:", recall_score(y_test, y_pred_lr, zero_division=0))
print("F1 Macro:", f1_score(y_test, y_pred_lr, average='macro'))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_lr))
# Out:
# Logistic Regression
# Accuracy: 0.6711247423198753
# Precision: 0.10951954640405849
# Recall: 0.5615914307574599
# F1 Macro: 0.48870062886577353
# ROC-AUC: 0.6567257418615657
